# %%
#practice matplot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
day=[1,2,3,4,5,6,7,8]
temp=[40,50,60,34,35,36,37,70]

# %%
plt.plot (day,temp,color="orange",linewidth=5,linestyle="dotted")

# %%
plt.plot (day,temp,color="black",linewidth=5,linestyle="dotted")

# %%
plt.plot (day,temp,color="black",linewidth=5,linestyle="dashed")

# %%
plt.plot (day,temp,color="black",linewidth=5,linestyle="dashdot")

# %%
plt.plot (day,temp,color="black",linewidth=5,linestyle="solid")

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.plot (day,temp,color="purple",linewidth=6,linestyle="solid")

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot (day,temp,color="purple",linewidth=6,linestyle="solid")

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot (day,temp,"b.",linewidth=555)

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot (day,temp,"r+--")

# %%
plt.xlabel("Days")
plt.ylabel("Temperature")
plt.title("Weather")
plt.plot (day,temp,"--rD")

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.gridspec as gridspec

# Fixing random state for reproducibility
np.random.seed(19680801)

dt = 0.01
t = np.arange(0, 10, dt)
nse = np.random.randn(len(t))
r = np.exp(-t / 0.05)

cnse = np.convolve(nse, r) * dt
cnse = cnse[:len(t)]
s = 0.1 * np.sin(2 * np.pi * t) + cnse

plt.subplot(211)
plt.plot(t, s)
plt.subplot(212)
plt.psd(s, 512, 1 / dt)

plt.show()

# %%
plt.plot (day,temp,color="#905030",marker="8",linewidth=1)

# %%
plt.plot (day,temp,color="#900020",marker="8",linewidth=1)

# %%
plt.plot (day,temp,color="#900020",marker="8",linewidth=1,alpha=1)

# %%
plt.plot (day,temp,color="#900020",marker="8",linewidth=1,alpha=0.5)

# %%
days=[1,2,3,4,5,6,7]
study_time=[10,12,13,14,15,16,20]
rest_time=[5,5,5,5,5,5,5]
play_time=[1,2,1,1,1,1,2]

# %%
plt.plot(days,study_time,rest_time,play_time)

# %%
plt.xlabel("day")
plt.ylabel("hour")
plt.title("daily activities")

plt.plot(days)
plt.plot(study_time)
plt.plot(rest_time)
plt.plot(play_time)

# %%
plt.xlabel("day")
plt.ylabel("hour")
plt.title("daily activities")

plt.plot(days)
plt.plot(study_time,label = "Study time")
plt.plot(rest_time, label = "Rest time")
plt.plot(play_time, label = "play time")
plt.legend()

# %%
plt.xlabel("day")
plt.ylabel("hour")
plt.title("daily activities")

plt.plot(days)
plt.plot(study_time,label = "Study time")
plt.plot(rest_time, label = "Rest time")
plt.plot(play_time, label = "play time")
plt.legend(loc="upper center")

# %%
plt.xlabel("day")
plt.ylabel("hour")
plt.title("daily activities")

plt.plot(days)
plt.plot(study_time,label = "Study time")
plt.plot(rest_time, label = "Rest time")
plt.plot(play_time, label = "play time")
plt.legend(loc="best",shadow=True,fontsize="small")

# %%
plt.xlabel("day")
plt.ylabel("hour")
plt.title("daily activities")

plt.plot(days)
plt.plot(study_time,label = "Study time")
plt.plot(rest_time, label = "Rest time")
plt.plot(play_time, label = "play time")
plt.legend(loc="best",shadow=True,fontsize="small")
#grid property
plt.grid()

# %%
#all value is in  assume
company=["Apple","Facebook","Microsoft","oracle","Cisco"]
revenue=[95,80,86,95,105]

# %% [markdown]
# # Bar Chart

# %%
plt.bar(company,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
# 
ind=np.arange(len(company))
ind
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.bar(ind,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
#xsticks fuction for string 
plt.xticks(ind,company)
plt.bar(ind,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
#change the position of string
plt.xticks(ind+.1,company)
plt.bar(ind,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
#change the position of string
plt.xticks(ind-.4,company)
plt.bar(ind,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
#complete graph
plt.xticks(ind,company)
plt.ylabel("Revenue in Billion")
plt.xlabel("company")
plt.title("Technology Stock")
plt.bar(ind,revenue)
# Out:
# <BarContainer object of 5 artists>

# %%
#complete graph
plt.xticks(ind,company)
plt.ylabel("Revenue in Billion")
plt.xlabel("company")
plt.title("Technology Stock")
plt.bar(ind,revenue,label="Revenue")
plt.legend()

# %%
#all value is in  assume
company=["Apple","Facebook","Microsoft","oracle","Cisco"]
revenue=[95,80,86,95,105]
profit=[45,55,35,80,65]

# %%
plt.xticks(ind,company)
plt.ylabel("Revenue in Billion")
plt.xlabel("company")
plt.title("Technology Stock")
plt.bar(ind,revenue,label="Revenue")
plt.bar(ind,profit,label="Profit")
plt.legend()
